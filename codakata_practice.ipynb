# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithramala92/Python/blob/main/codakata_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
multiples = []
for i in range(3):
    multiples.append(n * (i + 1))
print(*multiples)
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2581423984.py in <cell line: 0>()
#       1 n=int(input())
#       2 for i in range(3):
# ----> 3     s=s.append()
#       4 print(s)
#
# NameError: name 's' is not defined

# %%
n=int(input())
multiples=[]
for i in range(3):
  multiples.append(n*(i+1))
print(*multiples)
# Out:
# 3
# 3 6 9

# %%
n=int(input())
s=[]
if n==0:
    print("NULL")
else:
  for i in range(1, n + 1):
    s.append(9*i)
print(*s)
# Out:
# 3
# 9 18 27

# %%
a=int(input())
b=int(input())
c=int(input())
d=max(a,b,c)
print(d)
# Out:
# 567
# 234
# 345
# 567

# %%
c=float(input())
fr=((c*9)/5)+32

print(f'{fr:.2f}')
# Out:
# 50
# 122.00

# %%
a,n=map(int,input().split())
s=[]
for i in range(n):
    s.append(a)
print(*s)
# Out:
# 2 4
# 2 2 2 2
